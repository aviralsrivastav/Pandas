# %%
x=9
print(x)
# Out:
# 9

# %%
import pandas as pd

# %%
data = {
    "name":["sam","Yuri", "Nikolai"],
    "age":[29,30,32]
}

# %%
data
# Out:
# {'name': ['sam', 'Yuri', 'Nikolai'], 'age': [29, 30, 32]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       name  age
# 0      sam   29
# 1     Yuri   30
# 2  Nikolai   32

# %%
df1 = pd.read_csv('orders.csv')

# %%
df1
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.head()
# Out:
#       name  age
# 0      sam   29
# 1     Yuri   30
# 2  Nikolai   32

# %%
df1.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
df1.dtypes
# Out:
# order_id        object
# order_date      object
# ship_date       object
# ship_mode       object
# customer_id     object
# region          object
# product_id      object
# category        object
# sales          float64
# quantity         int64
# profit         float64
# dtype: object

# %%
df = pd.read_csv('orders.csv')

# %%
df.describe()
# Out:
#              sales   quantity       profit
# count    50.000000  50.000000    50.000000
# mean    300.792000   3.920000   -20.550000
# std     547.564035   1.977836   251.767027
# min       2.500000   2.000000 -1665.100000
# 25%      20.075000   2.000000     2.500000
# 50%      74.650000   3.000000     8.350000
# 75%     249.875000   5.000000    17.650000
# max    3083.400000   9.000000   240.300000

# %%
list(df)
# Out:
# ['order_id',
#  'order_date',
#  'ship_date',
#  'ship_mode',
#  'customer_id',
#  'region',
#  'product_id',
#  'category',
#  'sales',
#  'quantity',
#  'profit']

# %%
df.columns=[
 'order_date','order_id',
 'ship_date',
 'ship_mode',
 'customer_id',
 'region',
 'product_id',
 'category',
 'sales',
 'quantity',
 'profit']

# %%
df.head()
# Out:
#        order_date    order_id   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
df=pd.read_csv('orders.csv')
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id',
#        'region', 'product_id', 'category', 'sales', 'quantity', 'profit'],
#       dtype='object')

# %%
df.rename(columns={'ship_mode':'shipping_mode','order_id':'id'})
# Out:
#                 id  order_date   ship_date   shipping_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
col=['order_id','order_date','ship_date']
df[col]
# Out:
#           order_id  order_date   ship_date
# 0   CA-2020-152156  08-11-2020  11-11-2020
# 1   CA-2020-152156  08-11-2020  11-11-2020
# 2   CA-2020-138688  12-06-2020  16-06-2020
# 3   US-2019-108966  11-10-2019  18-10-2019
# 4   US-2019-108966  11-10-2019  18-10-2019
# 5   CA-2018-115812  09-06-2018  14-06-2018
# 6   CA-2018-115812  09-06-2018  14-06-2018
# 7   CA-2018-115812  09-06-2018  14-06-2018
# 8   CA-2018-115812  09-06-2018  14-06-2018
# 9   CA-2018-115812  09-06-2018  14-06-2018
# 10  CA-2018-115812  09-06-2018  14-06-2018
# 11  CA-2018-115812  09-06-2018  14-06-2018
# 12  CA-2021-114412  15-04-2021  20-04-2021
# 13  CA-2020-161389  05-12-2020  10-12-2020
# 14  US-2019-118983  22-11-2019  26-11-2019
# 15  US-2019-118983  22-11-2019  26-11-2019
# 16  CA-2018-105893  11-11-2018  18-11-2018
# 17  CA-2018-167164  13-05-2018  15-05-2018
# 18  CA-2018-143336  27-08-2018  01-09-2018
# 19  CA-2018-143336  27-08-2018  01-09-2018
# 20  CA-2018-143336  27-08-2018  01-09-2018
# ...

# %%
df[['order_id','order_date','ship_date']]
# Out:
#           order_id  order_date   ship_date
# 0   CA-2020-152156  08-11-2020  11-11-2020
# 1   CA-2020-152156  08-11-2020  11-11-2020
# 2   CA-2020-138688  12-06-2020  16-06-2020
# 3   US-2019-108966  11-10-2019  18-10-2019
# 4   US-2019-108966  11-10-2019  18-10-2019
# 5   CA-2018-115812  09-06-2018  14-06-2018
# 6   CA-2018-115812  09-06-2018  14-06-2018
# 7   CA-2018-115812  09-06-2018  14-06-2018
# 8   CA-2018-115812  09-06-2018  14-06-2018
# 9   CA-2018-115812  09-06-2018  14-06-2018
# 10  CA-2018-115812  09-06-2018  14-06-2018
# 11  CA-2018-115812  09-06-2018  14-06-2018
# 12  CA-2021-114412  15-04-2021  20-04-2021
# 13  CA-2020-161389  05-12-2020  10-12-2020
# 14  US-2019-118983  22-11-2019  26-11-2019
# 15  US-2019-118983  22-11-2019  26-11-2019
# 16  CA-2018-105893  11-11-2018  18-11-2018
# 17  CA-2018-167164  13-05-2018  15-05-2018
# 18  CA-2018-143336  27-08-2018  01-09-2018
# 19  CA-2018-143336  27-08-2018  01-09-2018
# 20  CA-2018-143336  27-08-2018  01-09-2018
# ...

# %%
type[data]
# Out:
# type[{'name': ['sam', 'Yuri', 'Nikolai'], 'age': [29, 30, 32]}]

# %%
type(data)
# Out:
# dict

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[1:10]
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 5  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 6  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 7  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 8  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 9  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
#
#         product_id         category  sales  quantity  profit
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# ...

# %%
df.set_index('order_id', inplace=True)

# %%
df.loc[['US-2019-108966','CA-2020-152156'],['ship_date']]
# Out:
#                  ship_date
# order_id
# US-2019-108966  18-10-2019
# US-2019-108966  18-10-2019
# CA-2020-152156  11-11-2020
# CA-2020-152156  11-11-2020

# %%
df
# Out:
#                 order_date   ship_date       ship_mode customer_id   region  \
# order_id
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520    South
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520    South
# CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045     West
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335    South
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335    South
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# ...

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
df.sort_index(ascending=False).head()
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 49  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
# 48  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 47  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 46  CA-2018-146703  20-10-2018  25-10-2018    Second Class    PO-18865
# 45  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
#
#      region       product_id         category  sales  quantity  profit
# 49  Central  OFF-BI-10004410  Office Supplies   38.2         6    18.0
# 48     East  TEC-PH-10003988       Technology   21.8         2     6.1
# 47     East  TEC-AC-10002167       Technology   45.0         3     5.0
# 46  Central  OFF-ST-10001713  Office Supplies  212.0         4     8.5
# 45  Central  OFF-BI-10003291  Office Supplies   17.5         2     8.2

# %%
df.sort_values('sales',ascending=False)
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 27  US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 35  CA-2020-117590  08-12-2020  10-12-2020     First Class    GH-14485
# 24  CA-2019-106320  25-09-2019  30-09-2019  Standard Class    EB-13870
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 16  CA-2018-105893  11-11-2018  18-11-2018  Standard Class    PK-19075
# 38  CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710
# 13  CA-2020-161389  05-12-2020  10-12-2020  Standard Class    IM-15070
# 40  CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710
# ...

# %%
df.sort_values(['quantity','profit'],ascending=[False,False])
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id region  \
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710  south
# 37  CA-2019-117415  27-12-2019  31-12-2019  Standard Class    SN-20710  south
# 35  CA-2020-117590  08-12-2020  10-12-2020     First Class    GH-14485  south
# 22  CA-2020-137330  09-12-2020  13-12-2020  Standard Class    KB-16585  south
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710  south
# 21  CA-2020-137330  09-12-2020  13-12-2020  Standard Class    KB-16585  south
# 27  US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520  south
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710  south
# 49  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000  south
# 16  CA-2018-105893  11-11-2018  18-11-2018  Standard Class    PK-19075  south
# 31  US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520  south
# ...

# %%
fc = ~(df['region']=='south')
df.loc[fc].head()
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, ship_date, ship_mode, customer_id, region, product_id, category, sales, quantity, profit]
# Index: []

# %%
df.loc[df['region']=='south', ['order_id','quantity']]
# Out:
#           order_id  quantity
# 0   CA-2020-152156         2
# 1   CA-2020-152156         3
# 2   CA-2020-138688         2
# 3   US-2019-108966         5
# 4   US-2019-108966         2
# 5   CA-2018-115812         7
# 6   CA-2018-115812         4
# 7   CA-2018-115812         6
# 8   CA-2018-115812         3
# 9   CA-2018-115812         5
# 10  CA-2018-115812         9
# 11  CA-2018-115812         4
# 12  CA-2021-114412         3
# 13  CA-2020-161389         3
# 14  US-2019-118983         5
# 15  US-2019-118983         3
# 16  CA-2018-105893         6
# 17  CA-2018-167164         2
# 18  CA-2018-143336         2
# 19  CA-2018-143336         3
# 20  CA-2018-143336         4
# 21  CA-2020-137330         7
# 22  CA-2020-137330         7
# 23  US-2021-156909         2
# 24  CA-2019-106320         3
# 25  CA-2020-121755         2
# 26  CA-2020-121755         3
# 27  US-2019-150630         7
# 28  US-2019-150630         2
# 29  US-2019-150630         3
# 30  US-2019-150630         2
# ...

# %%
df[~(df['region']=='south')]
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, ship_date, ship_mode, customer_id, region, product_id, category, sales, quantity, profit]
# Index: []

# %%
df[~(df['region'].str.lower().str.strip() == 'south')]
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, ship_date, ship_mode, customer_id, region, product_id, category, sales, quantity, profit]
# Index: []

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id region  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  south
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  south
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045  south
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  south
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  south
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710  south
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710  south
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710  south
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710  south
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710  south
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710  south
# ...

# %%
df = pd.read_csv('orders.csv')

# %%
df[~(df['region']=='south') | ~(df['region']=='South')]
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df[~(df['region'].str.lower().str.strip() == 'south')]
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 13  CA-2020-161389  05-12-2020  10-12-2020  Standard Class    IM-15070
# 14  US-2019-118983  22-11-2019  26-11-2019  Standard Class    HP-14815
# 15  US-2019-118983  22-11-2019  26-11-2019  Standard Class    HP-14815
# 16  CA-2018-105893  11-11-2018  18-11-2018  Standard Class    PK-19075
# ...

# %%
df['country']='India'

# %%
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit country
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9   India
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6   India
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9   India
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0   India
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5   India

# %%
df['original_price'] = df['sales'] - df['profit']

# %%
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit country  \
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9   India
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6   India
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9   India
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0   India
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5   India
#
#    original_price
# 0           220.1
# 1           512.3
# 2             7.7
# ...

# %%
df.drop(columns=['country','original_price'], inplace=True)

# %%
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
df['profit_flag']='loss'

# %%
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit profit_flag
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9        loss
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6        loss
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9        loss
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0        loss
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5        loss

# %%
df.loc[(df['profit']>0) & (df['profit']<=50) ,'profit_flag']='mild profit'

# %%
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit  profit_flag
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9  mild profit
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6         loss
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9  mild profit
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0         loss
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5  mild profit

# %%
df.loc[df['profit']>50, 'profit_flag']='high'

# %%
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit  profit_flag
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9  mild profit
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6         high
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9  mild profit
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0         loss
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5  mild profit

# %%
df.drop(columns='profit_flag', inplace=True)

# %%
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
df['lencat']=df['category'].apply(len)

# %%
def profit_loss(profit):
    if profit>0:
        return "Profit"
    else:
        return "Loss"
df['P/L'] = df['profit'].apply(profit_loss)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df['capsize'] = df['region'].str.capitalize()

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.isnull()
# Out:
#     order_id  order_date  ship_date  ship_mode  customer_id  region  \
# 0      False       False      False      False        False   False
# 1      False       False      False      False        False   False
# 2      False       False      False      False        False   False
# 3      False       False      False      False        False   False
# 4      False       False      False      False        False   False
# 5      False       False      False      False        False   False
# 6      False       False      False      False        False   False
# 7      False       False      False      False        False   False
# 8      False       False      False      False        False   False
# 9      False       False      False      False        False   False
# 10     False       False      False      False        False   False
# 11     False       False      False      False        False   False
# 12     False       False      False      False        False   False
# ...

# %%
df.isnull().sum()
# Out:
# order_id       0
# order_date     0
# ship_date      0
# ship_mode      0
# customer_id    0
# region         0
# product_id     0
# category       0
# sales          0
# quantity       0
# profit         0
# lencat         0
# P/L            0
# capsize        0
# dtype: int64

# %%
df.dropna()
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.dropna(subset=['sales'])
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.fillna("Unknown")
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df["category"].fillna("MyText")
# Out:
# 0           Furniture
# 1           Furniture
# 2     Office Supplies
# 3           Furniture
# 4     Office Supplies
# 5           Furniture
# 6     Office Supplies
# 7          Technology
# 8     Office Supplies
# 9     Office Supplies
# 10          Furniture
# 11         Technology
# 12    Office Supplies
# 13    Office Supplies
# 14    Office Supplies
# 15    Office Supplies
# 16    Office Supplies
# 17    Office Supplies
# 18    Office Supplies
# 19         Technology
# 20    Office Supplies
# 21    Office Supplies
# 22    Office Supplies
# 23          Furniture
# 24          Furniture
# 25    Office Supplies
# 26         Technology
# 27          Furniture
# 28    Office Supplies
# 29          Furniture
# 30    Office Supplies
# 31    Office Supplies
# 32    Office Supplies
# 33    Office Supplies
# 34    Office Supplies
# 35         Technology
# 36          Furniture
# 37    Office Supplies
# 38          Furniture
# 39          Furniture
# 40         Technology
# ...

# %%
df["sales"].fillna(df["sales"].mean())
# Out:
# 0      262.0
# 1      731.9
# 2       14.6
# 3      957.6
# 4       22.4
# 5       48.9
# 6        7.3
# 7      907.2
# 8       18.5
# 9      114.9
# 10    1706.2
# 11     911.4
# 12      15.6
# 13     408.0
# 14      68.8
# 15       2.5
# 16     665.9
# 17      55.5
# 18       8.6
# 19     213.5
# 20      22.7
# 21      19.5
# 22      60.3
# 23      71.4
# 24    1044.6
# 25      11.6
# 26      90.6
# 27    3083.4
# 28       9.6
# 29     124.2
# 30       3.3
# 31      86.3
# 32       6.9
# 33      15.8
# 34      29.5
# 35    1097.5
# 36     190.9
# 37     113.3
# 38     532.4
# 39     212.1
# 40     371.2
# 41     147.2
# 42      77.9
# 43      95.6
# 44      46.0
# 45      17.5
# 46     212.0
# 47      45.0
# 48      21.8
# 49      38.2
# Name: sales, dtype: float64

# %%
#df.fillna(method="ffill")  #forwardfill
df.ffill() #forwarddill
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.bfill() #backwardfill
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
dataa = {
    "name":["A","B","C","C"],
    "class":["1","2","4","3"],
    "sal":[1000,1000,2000,2000]
}

# %%
dataa
# Out:
# {'name': ['A', 'B', 'C', 'C'],
#  'class': ['1', '2', '4', '3'],
#  'sal': [1000, 1000, 2000, 2000]}

# %%
dff = pd.DataFrame(dataa)

# %%
dff
# Out:
#   name class   sal
# 0    A     1  1000
# 1    B     2  1000
# 2    C     4  2000
# 3    C     3  2000

# %%
dff.drop_duplicates(keep = 'last')
# Out:
#   name class   sal
# 0    A     1  1000
# 1    B     2  1000
# 3    C     3  2000

# %%
dff.drop_duplicates(subset='sal')
# Out:
#   name class   sal
# 0    A     1  1000
# 2    C     3  2000

# %%
dff
# Out:
#   name class   sal
# 0    A     1  1000
# 1    B     2  1000
# 2    C     4  2000
# 3    C     3  2000

# %%
dff.drop_duplicates(subset = ['name','sal'],keep='last')
#dff.drop_duplicates(subset=['name', 'sal'], keep='last')
# Out:
#   name class   sal
# 0    A     1  1000
# 1    B     2  1000
# 3    C     3  2000

# %% [markdown]
# # Date Time Functions in Pandas

# %%
df= pd.read_csv('orders.csv')

# %%
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
df.dtypes
# Out:
# order_id               object
# order_date     datetime64[ns]
# ship_date              object
# ship_mode              object
# customer_id            object
# region                 object
# product_id             object
# category               object
# sales                 float64
# quantity                int64
# profit                float64
# dtype: object

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format="%d-%m-%Y")

# %%
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
df.head()
# Out:
#          order_id order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156 2020-11-08  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156 2020-11-08  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688 2020-06-12  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966 2019-10-11  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966 2019-10-11  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
df.dtypes
# Out:
# order_id               object
# order_date     datetime64[ns]
# ship_date              object
# ship_mode              object
# customer_id            object
# region                 object
# product_id             object
# category               object
# sales                 float64
# quantity                int64
# profit                float64
# dtype: object

# %%
df['ship_date'] = pd.to_datetime(df['ship_date'], format="%d-%m-%Y")

# %%
df.head()
# Out:
#          order_id order_date  ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520  South
# 1  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520  South
# 2  CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045   West
# 3  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335  South
# 4  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5

# %%
df.dtypes
# Out:
# order_id               object
# order_date     datetime64[ns]
# ship_date      datetime64[ns]
# ship_mode              object
# customer_id            object
# region                 object
# product_id             object
# category               object
# sales                 float64
# quantity                int64
# profit                float64
# dtype: object

# %%
df['order_date'].head().dt.year
# Out:
# 0    2020
# 1    2020
# 2    2020
# 3    2019
# 4    2019
# Name: order_date, dtype: int32

# %%
df['order_date'].head().dt.month
# Out:
# 0    11
# 1    11
# 2     6
# 3    10
# 4    10
# Name: order_date, dtype: int32

# %%
df[df["order_date"] >= "2021-01-01" ]
# Out:
#           order_id order_date  ship_date       ship_mode customer_id   region  \
# 12  CA-2021-114412 2021-04-15 2021-04-20  Standard Class    AA-10480    South
# 23  US-2021-156909 2021-07-16 2021-07-18    Second Class    SF-20065     East
# 34  CA-2021-107727 2021-10-19 2021-10-23    Second Class    MA-17560  Central
# 41  CA-2021-120999 2021-09-10 2021-09-15  Standard Class    LC-16930  Central
# 43  CA-2021-139619 2021-09-19 2021-09-23  Standard Class    ES-14080    South
#
#          product_id         category  sales  quantity  profit
# 12  OFF-PA-10002365  Office Supplies   15.6         3     5.4
# 23  FUR-CH-10002774        Furniture   71.4         2    -1.0
# 34  OFF-PA-10000249  Office Supplies   29.5         3     9.9
# 41  TEC-PH-10004093       Technology  147.2         4    16.6
# 43  OFF-ST-10003282  Office Supplies   95.6         2     9.6

# %%
df.dtypes
# Out:
# order_id               object
# order_date     datetime64[ns]
# ship_date      datetime64[ns]
# ship_mode              object
# customer_id            object
# region                 object
# product_id             object
# category               object
# sales                 float64
# quantity                int64
# profit                float64
# dtype: object

# %%
df['transit_days'] = (df["ship_date"]-df["order_date"]).dt.days

# %%
df.head()
# Out:
#          order_id order_date  ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520  South
# 1  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520  South
# 2  CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045   West
# 3  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335  South
# 4  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit  transit_days
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9             3
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6             3
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9             4
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0             7
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5             7

# %% [markdown]
# # Aggregations in Pandas

# %%
df['sales'].sum()
# Out:
# np.float64(15039.599999999999)

# %%
df['sales'].min()
# Out:
# np.float64(2.5)

# %%
df['sales'].max()
# Out:
# np.float64(3083.4)

# %%
df['sales'].mean()
# Out:
# np.float64(300.792)

# %%
df['sales'].median()
# Out:
# np.float64(74.65)

# %%
df['sales'].count()
# Out:
# np.int64(50)

# %%
df['sales'].std()
# Out:
# np.float64(547.564035148178)

# %%
df["sales"].nunique()
# Out:
# 50

# %%
df['category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df.groupby(['category'])

# %%
df.groupby(['category'])['sales'].sum()
# Out:
# category
# Furniture          8965.6
# Office Supplies    2222.6
# Technology         3851.4
# Name: sales, dtype: float64

# %%
df.groupby(["category"])["sales"].mean()
# Out:
# category
# Furniture          747.133333
# Office Supplies     79.378571
# Technology         385.140000
# Name: sales, dtype: float64

# %%
df.groupby(["region"])["sales"].agg(["min","max","mean","sum","count"])
# Out:
#           min     max        mean     sum  count
# region
# Central   2.5  1097.5  224.988235  3824.8     17
# East      3.3  3083.4  346.770000  3467.7     10
# South    15.6   957.6  347.516667  2085.1      6
# West      7.3  1706.2  333.058824  5662.0     17

# %%
df.groupby(["category"]).agg({'sales':'sum', 'profit':'sum'})
# Out:
#                   sales  profit
# category
# Furniture        8965.6 -1642.4
# Office Supplies  2222.6   215.2
# Technology       3851.4   399.7

# %%
df['category'].value_counts()
# Out:
# category
# Office Supplies    28
# Furniture          12
# Technology         10
# Name: count, dtype: int64

# %% [markdown]
# # Pivot Table

# %%
pd.pivot_table(
    df,
    index="region",
    columns = "category",
    values = "sales",
    aggfunc = "sum",
    fill_value = 0.00

)
# Out:
# category  Furniture  Office Supplies  Technology
# region
# Central       935.4           1227.5      1661.9
# East         3279.0            121.9        66.8
# South        1951.5            133.6         0.0
# West         2799.7            739.6      2122.7

# %% [markdown]
# # Jioning and Merging of DataFrames

# %%
df_orders = pd.read_csv("orders.csv")

# %%
df_returns = pd.read_csv("returns.csv")

# %%
df_returns
# Out:
#   return_order_id return_reason
# 0  CA-2018-105893   bad quality
# 1  CA-2018-143336    wrong item
# 2  CA-2018-146703    wrong item
# 3  CA-2018-167164         other
# 4  CA-2019-106320   bad quality
# 5  CA-2019-115742         other
# 6  CA-2020-101343   bad quality
# 7  CA-2020-117590    wrong item

# %%
df_orders.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5
